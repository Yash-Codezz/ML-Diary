# %% [markdown]
# # Lasso Regularization.

# %% [markdown]
# ---

# %%
import time

import numpy as np

import pandas as pd

import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split, GridSearchCV, cross_val_score
from sklearn.linear_model import Lasso
from sklearn.metrics import r2_score, mean_absolute_percentage_error

# %%
data = pd.read_csv("house_prices_preprocessed.csv")

# %%
data.drop(columns=['Unnamed: 0'], inplace=True)

# %% [markdown]
# ## Train-Test-Split:

# %%
X = data.drop(columns=['SalePrice'])
y = data['SalePrice']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=69)

# %% [markdown]
# ## Building Model using sklearn:

# %%
param = {'alpha' : [0.001, 0.01, 0.1, 1, 10, 100, 1000]}

grid = GridSearchCV(
    estimator=Lasso(),
    scoring='r2',
    param_grid=param,
    n_jobs=-1,
    cv=5
)

grid.fit(X_train, y_train)
# Out:
# GridSearchCV(cv=5, estimator=Lasso(), n_jobs=-1,
#              param_grid={'alpha': [0.001, 0.01, 0.1, 1, 10, 100, 1000]},
#              scoring='r2')

# %%
print(f"Best parameters: {grid.best_params_}")
print(f"Best Score: {grid.best_score_ * 100 :.2f}%")
# Out:
# Best parameters: {'alpha': 10}
# Best Score: 83.84%

# %%
L1 = Lasso(alpha=10)

start_time = time.time()
L1.fit(X_train, y_train)
end_time = time.time() - start_time

print("Model Trained Successfully!")
print(f"Time Taken For Training: {end_time:.2f}s")
# Out:
# Model Trained Successfully!
# Time Taken For Training: 0.01s

# %% [markdown]
# ## Results:

# %%
y_pred = L1.predict(X_test)

print(f"r2 Score: {r2_score(y_test, y_pred)*100:.2f}%")
print(f"\nmean absolute error: {(mean_absolute_percentage_error(y_test, y_pred)*100):.2f}%")
# Out:
# r2 Score: 80.33%
#
# mean absolute error: 9.13%

# %%
print(f"r2 Score: {np.mean(cross_val_score(estimator=L1, X=X, y=y, scoring='r2', cv=10, n_jobs=-1)) * 100:.2f}%")
# Out:
# r2 Score: 82.84%

# %%
print(f"mean absolute error: {-np.mean(cross_val_score(estimator=L1, X=X, y=y, scoring='neg_mean_absolute_percentage_error', cv=10, n_jobs=-1)) * 100:.2f}%")
# Out:
# mean absolute error: 9.64%

# %% [markdown]
# ## Building Model using Gradient Descent:

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()

X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %%
class lasso:

    def __init__(self, learning_rate=0.01, max_iter=100, alpha=1):
        self.alpha = alpha
        self.learning_rate = learning_rate
        self.max_iter = max_iter
        self.intercept = None
        self.coef = None
        self.loss = []

    def fit(self, X_train, y_train):

        self.X_train = X_train
        self.y_train = y_train

        self.intercept = 0
        self.coef = np.ones(self.X_train.shape[1])
        self.X_train = np.insert(self.X_train, 0, 1, axis=1)
        beta = np.insert(self.coef, 0, self.intercept)

        for i in range(self.max_iter):
            slope = (2 / X_train.shape[0]) * (np.dot(self.X_train.T, self.X_train).dot(beta) - np.dot(self.X_train.T, self.y_train))
            slope[1:] += self.alpha * np.sign(beta[1:])
            beta = beta - (self.learning_rate * slope)

            loss = np.mean((self.y_train - np.dot(self.X_train, beta)) ** 2) + self.alpha * np.sum(np.abs(beta[1:]))
            self.loss.append(loss)

        self.intercept = beta[0]
        self.coef = beta[1:]

    def predict(self, X_test):

        return self.intercept + np.dot(X_test, self.coef)

# %%
l1 = lasso(learning_rate=0.1, max_iter=100, alpha=10)

start_time = time.time()
l1.fit(X_train_scaled, y_train)
end_time = time.time() - start_time

print("Model Trained Successfully!")
print(f"Time Taken For Training: {end_time:.2f}s")
# Out:
# Model Trained Successfully!
# Time Taken For Training: 0.11s

# %%
y_pred = l1.predict(X_test_scaled)

print(f"r2 Score: {r2_score(y_test, y_pred)*100:.2f}%")
print(f"\nmean absolute error: {(mean_absolute_percentage_error(y_test, y_pred)*100):.2f}%")
# Out:
# r2 Score: 80.33%
#
# mean absolute error: 9.13%

# %%
plt.plot(range(1, len(l1.loss) + 1), l1.loss)
plt.xlabel("Iterations")
plt.ylabel("Loss (MSE)")
plt.title("Loss vs Iterations")
plt.show()
