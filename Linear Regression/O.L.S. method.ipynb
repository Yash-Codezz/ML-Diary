# %% [markdown]
# # Linear Regression Build using O.L.S Method.

# %% [markdown]
# ---

# %%
import time

import numpy as np

import pandas as pd

from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score, mean_absolute_percentage_error

# %%
data = pd.read_csv("house_prices_preprocessed.csv")

# %%
data.drop(columns=['Unnamed: 0'], inplace=True)

# %% [markdown]
# ## Train-Test-Split:

# %%
X = data.drop(columns=['SalePrice'])
y = data['SalePrice']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=69)

# %% [markdown]
# ## Building Model:

# %%
class LinearRegression:

    def __init__(self):
        self.coef = None
        self.intercept = None

    def fit(self, X_train, y_train):
        X_train = np.insert(X_train, 0, 1, axis=1)
        betas = np.linalg.inv(np.dot(X_train.T, X_train)).dot(X_train.T).dot(y_train)

        self.intercept = betas[0]
        self.coef = betas[1:]

    def predict(self, X_test):
        return self.intercept + np.dot(X_test, self.coef)

# %%
Lr = LinearRegression()

start_time = time.time()
Lr.fit(X_train, y_train)
end_time = time.time() - start_time

print("Model Trained Successfully!")
print(f"Time Taken for training: {end_time:.2f}s")
# Out:
# Model Trained Successfully!
# Time Taken for training: 0.01s

# %% [markdown]
# ## Result:

# %%
y_pred = Lr.predict(X_test)

print(f"r2_score: {(r2_score(y_test, y_pred)*100):.2f}%")
print(f"\nmean_absolute_percentage_error: {(mean_absolute_percentage_error(y_test, y_pred)*100):.2f}%")
# Out:
# r2_score: 80.33%
#
# mean_absolute_percentage_error: 9.13%
